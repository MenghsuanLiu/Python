# %%
# Imports the Google Cloud client library
from google.cloud import vision
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "D:/MyDocument/GCP_KEY/service-key.json"

def detect_labels(path):

    client = vision.ImageAnnotatorClient()
    # rb = read binary
    with open(path, "rb") as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.label_detection(image=image)
    labels = response.label_annotations
    print("Labels:")

    for label in labels:
        print(label.description)

    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )

detect_labels("D:/GitHub/Python/Python與AI大型語言模型開發班/image/cat1.jpg")
# Out:
# Labels:
# Eye
# Cat
# Carnivore
# Felidae
# Small to medium-sized cats
# Whiskers
# Fawn
# Snout
# Tail
# Terrestrial animal

# %%
import tkinter as tk

class Calculator:
    def __init__(self, master):
        self.master = master
        master.title("Basic Calculator")

        # Create display
        self.display = tk.Entry(master, width=30, justify='right')
        self.display.grid(row=0, column=0, columnspan=4, padx=5, pady=5)

        # Create buttons
        self.create_button('7', 1, 0)
        self.create_button('8', 1, 1)
        self.create_button('9', 1, 2)
        self.create_button('/', 1, 3)

        self.create_button('4', 2, 0)
        self.create_button('5', 2, 1)
        self.create_button('6', 2, 2)
        self.create_button('*', 2, 3)

        self.create_button('1', 3, 0)
        self.create_button('2', 3, 1)
        self.create_button('3', 3, 2)
        self.create_button('-', 3, 3)

        self.create_button('0', 4, 0)
        self.create_button('.', 4, 1)
        self.create_button('C', 4, 2)
        self.create_button('+', 4, 3)

        self.create_button('=', 5, 0, columnspan=4)

    def create_button(self, text, row, column, columnspan=1):
        button = tk.Button(self.master, text=text, command=lambda: self.click(text))
        button.grid(row=row, column=column, columnspan=columnspan, padx=5, pady=5)

    def click(self, key):
        if key == '=':
            try:
                result = eval(self.display.get())
                self.display.delete(0, tk.END)
                self.display.insert(tk.END, str(result))
            except:
                self.display.delete(0, tk.END)
                self.display.insert(tk.END, "Error")
        elif key == 'C':
            self.display.delete(0, tk.END)
        else:
            self.display.insert(tk.END, key)

root = tk.Tk()
calculator = Calculator(root)
root.mainloop()

# %%
import tkinter as tk
from tkinter import font as tkfont

class Calculator:
    def __init__(self, master):
        self.master = master
        master.title("Stylish Calculator")
        master.configure(bg='#2C3E50')  # Dark blue background

        # Custom fonts
        self.display_font = tkfont.Font(family="Arial", size=18, weight="bold")
        self.button_font = tkfont.Font(family="Arial", size=14)

        # Create display
        self.display = tk.Entry(master, width=20, justify='right', font=self.display_font, bg='#ECF0F1', fg='#2C3E50')
        self.display.grid(row=0, column=0, columnspan=4, padx=5, pady=15, sticky='nsew')

        # Button colors
        self.num_color = '#3498DB'  # Light blue for numbers
        self.op_color = '#E74C3C'   # Red for operators
        self.eq_color = '#2ECC71'   # Green for equals
        self.clear_color = '#F39C12'  # Orange for clear

        # Create buttons
        button_data = [
            ('7', 1, 0, self.num_color), ('8', 1, 1, self.num_color), ('9', 1, 2, self.num_color), ('/', 1, 3, self.op_color),
            ('4', 2, 0, self.num_color), ('5', 2, 1, self.num_color), ('6', 2, 2, self.num_color), ('*', 2, 3, self.op_color),
            ('1', 3, 0, self.num_color), ('2', 3, 1, self.num_color), ('3', 3, 2, self.num_color), ('-', 3, 3, self.op_color),
            ('0', 4, 0, self.num_color), ('.', 4, 1, self.num_color), ('C', 4, 2, self.clear_color), ('+', 4, 3, self.op_color),
            ('=', 5, 0, self.eq_color, 4)
        ]

        for button in button_data:
            self.create_button(*button)

        # Configure grid
        for i in range(6):
            master.grid_rowconfigure(i, weight=1)
        for i in range(4):
            master.grid_columnconfigure(i, weight=1)

    def create_button(self, text, row, column, bg_color, columnspan=1):
        button = tk.Button( self.master, text=text, command=lambda: self.click(text),
                            font=self.button_font, bg=bg_color, fg='white', 
                            activebackground='#34495E', activeforeground='white')
        button.grid(row=row, column=column, columnspan=columnspan, padx=5, pady=5, sticky='nsew')

    def click(self, key):
        if key == '=':
            try:
                result = eval(self.display.get())
                self.display.delete(0, tk.END)
                self.display.insert(tk.END, str(result))
            except:
                self.display.delete(0, tk.END)
                self.display.insert(tk.END, "Error")
        elif key == 'C':
            self.display.delete(0, tk.END)
        else:
            self.display.insert(tk.END, key)

root = tk.Tk()
root.geometry("300x400")  # Set initial size
calculator = Calculator(root)
root.mainloop()

# %%
import pygame
import random

# Initialize Pygame
pygame.init()

# Colors
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLACK = (0, 0, 0)

# Screen dimensions
WIDTH = 800
HEIGHT = 600

# Snake and food size
BLOCK_SIZE = 20

# Initialize screen
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption('Snake Game')

clock = pygame.time.Clock()

class Snake:
    def __init__(self):
        self.body = [(WIDTH//2, HEIGHT//2)]
        self.direction = 'RIGHT'

    def move(self):
        x, y = self.body[0]
        if self.direction == 'UP':
            y -= BLOCK_SIZE
        elif self.direction == 'DOWN':
            y += BLOCK_SIZE
        elif self.direction == 'LEFT':
            x -= BLOCK_SIZE
        elif self.direction == 'RIGHT':
            x += BLOCK_SIZE
        self.body.insert(0, (x, y))

    def grow(self):
        self.body.append(self.body[-1])

    def check_collision(self):
        x, y = self.body[0]
        return (x < 0 or x >= WIDTH or y < 0 or y >= HEIGHT or
                (x, y) in self.body[1:])

def generate_food():
    while True:
        x = random.randrange(0, WIDTH, BLOCK_SIZE)
        y = random.randrange(0, HEIGHT, BLOCK_SIZE)
        if (x, y) not in snake.body:
            return x, y

def draw_snake(snake):
    for segment in snake.body:
        pygame.draw.rect(screen, GREEN, (*segment, BLOCK_SIZE, BLOCK_SIZE))

def draw_food(food):
    pygame.draw.rect(screen, RED, (*food, BLOCK_SIZE, BLOCK_SIZE))

snake = Snake()
food = generate_food()
score = 0

font = pygame.font.SysFont(None, 36)

running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_UP and snake.direction != 'DOWN':
                snake.direction = 'UP'
            elif event.key == pygame.K_DOWN and snake.direction != 'UP':
                snake.direction = 'DOWN'
            elif event.key == pygame.K_LEFT and snake.direction != 'RIGHT':
                snake.direction = 'LEFT'
            elif event.key == pygame.K_RIGHT and snake.direction != 'LEFT':
                snake.direction = 'RIGHT'

    snake.move()

    if snake.body[0] == food:
        snake.grow()
        food = generate_food()
        score += 1

    if snake.check_collision():
        running = False

    screen.fill(BLACK)
    draw_snake(snake)
    draw_food(food)

    score_text = font.render(f'Score: {score}', True, WHITE)
    screen.blit(score_text, (10, 10))

    pygame.display.flip()
    clock.tick(10)  # Controls the speed of the game

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import random
import sys

# Initialize Pygame
pygame.init()

# Colors
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
DARK_GREEN = (0, 100, 0)
BLACK = (0, 0, 0)
YELLOW = (255, 255, 0)

# Screen dimensions
WIDTH = 800
HEIGHT = 600

# Snake and food size
BLOCK_SIZE = 20

# Initialize screen
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption('Enhanced Snake Game')

clock = pygame.time.Clock()

class Snake:
    def __init__(self):
        self.body = [(WIDTH//2, HEIGHT//2)]
        self.direction = 'RIGHT'
        self.color = GREEN
        self.head_color = DARK_GREEN

    def move(self):
        x, y = self.body[0]
        if self.direction == 'UP':
            y -= BLOCK_SIZE
        elif self.direction == 'DOWN':
            y += BLOCK_SIZE
        elif self.direction == 'LEFT':
            x -= BLOCK_SIZE
        elif self.direction == 'RIGHT':
            x += BLOCK_SIZE
        self.body.insert(0, (x, y))
        self.body.pop()  # Remove the last segment unless grow() is called

    def grow(self):
        # Duplicate the last segment
        self.body.append(self.body[-1])

    def check_collision(self):
        x, y = self.body[0]
        return (x < 0 or x >= WIDTH or y < 0 or y >= HEIGHT or
                (x, y) in self.body[1:])

def generate_food():
    while True:
        x = random.randrange(0, WIDTH, BLOCK_SIZE)
        y = random.randrange(0, HEIGHT, BLOCK_SIZE)
        if (x, y) not in snake.body:
            return x, y

def draw_snake(snake):
    for i, segment in enumerate(snake.body):
        color = snake.head_color if i == 0 else snake.color
        pygame.draw.rect(screen, color, (*segment, BLOCK_SIZE, BLOCK_SIZE))
        pygame.draw.rect(screen, DARK_GREEN, (*segment, BLOCK_SIZE, BLOCK_SIZE), 1)

def draw_food(food):
    pygame.draw.rect(screen, RED, (*food, BLOCK_SIZE, BLOCK_SIZE))
    pygame.draw.rect(screen, YELLOW, (*food, BLOCK_SIZE, BLOCK_SIZE), 1)

def show_score(score):
    font = pygame.font.SysFont('arial', 30)
    score_surface = font.render(f'Score: {score}', True, WHITE)
    score_rect = score_surface.get_rect()
    score_rect.topleft = (10, 10)
    screen.blit(score_surface, score_rect)

def show_game_over(score):
    font = pygame.font.SysFont('arial', 50)
    game_over_surface = font.render('GAME OVER', True, RED)
    game_over_rect = game_over_surface.get_rect()
    game_over_rect.midtop = (WIDTH // 2, HEIGHT // 4)
    screen.blit(game_over_surface, game_over_rect)
    
    score_surface = font.render(f'Score: {score}', True, WHITE)
    score_rect = score_surface.get_rect()
    score_rect.midtop = (WIDTH // 2, game_over_rect.bottom + 20)
    screen.blit(score_surface, score_rect)
    
    restart_surface = font.render('Press SPACE to Restart', True, YELLOW)
    restart_rect = restart_surface.get_rect()
    restart_rect.midtop = (WIDTH // 2, score_rect.bottom + 20)
    screen.blit(restart_surface, restart_rect)
    
    pygame.display.flip()

def game_loop():
    global snake  # Make snake global so it can be accessed in generate_food()
    snake = Snake()
    food = generate_food()
    score = 0

    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_UP and snake.direction != 'DOWN':
                    snake.direction = 'UP'
                elif event.key == pygame.K_DOWN and snake.direction != 'UP':
                    snake.direction = 'DOWN'
                elif event.key == pygame.K_LEFT and snake.direction != 'RIGHT':
                    snake.direction = 'LEFT'
                elif event.key == pygame.K_RIGHT and snake.direction != 'LEFT':
                    snake.direction = 'RIGHT'

        snake.move()

        # Check if snake has eaten the food
        if snake.body[0] == food:
            snake.grow()  # Snake grows when it eats food
            food = generate_food()
            score += 1

        # Check for collision with walls or self
        if snake.check_collision():
            show_game_over(score)
            waiting = True
            while waiting:
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        sys.exit()
                    if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                        waiting = False
                        return  # Restart the game

        screen.fill(BLACK)
        draw_snake(snake)
        draw_food(food)
        show_score(score)

        pygame.display.flip()
        clock.tick(10 + score // 5)  # Increase speed as score increases

# Main game loop
while True:
    game_loop()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
